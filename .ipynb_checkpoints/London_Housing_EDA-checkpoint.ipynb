# %%
import pandas as pd
housing_data = pd.read_csv('housing_in_london_monthly_variables.csv')
housing_data.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %%
housing_data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# borough_flag     13549
# dtype: int64

# %%
housing_data.isnull()
# Out:
#         date   area  average_price   code  houses_sold  no_of_crimes  \
# 0      False  False          False  False        False          True
# 1      False  False          False  False        False          True
# 2      False  False          False  False        False          True
# 3      False  False          False  False        False          True
# 4      False  False          False  False        False          True
# ...      ...    ...            ...    ...          ...           ...
# 13544  False  False          False  False        False          True
# 13545  False  False          False  False        False          True
# 13546  False  False          False  False        False          True
# 13547  False  False          False  False         True          True
# 13548  False  False          False  False         True          True
#
#        borough_flag
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...

# %%
housing_data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# borough_flag        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(housing_data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# A. Convert the datatype of 'Date' column to date-time format.

# %%
housing_data.date = pd.to_datetime(housing_data.date)
housing_data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# borough_flag              int64
# dtype: object

# %% [markdown]
# B1. Add a new column "year" in the dataframe, which contains years only.

# %%
housing_data['year'] = housing_data.date.dt.year
housing_data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag  year
# 0           NaN             1  1995
# 1           NaN             1  1995
# 2           NaN             1  1995
# 3           NaN             1  1995
# 4           NaN             1  1995

# %% [markdown]
# B2. Add a new column "month" as the second column in the dataframe, which contains month only.

# %%
housing_data.insert(1, 'month', housing_data.date.dt.month)
housing_data.head()
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
# 2 1995-03-01      3  city of london          79121  E09000001         14.0
# 3 1995-04-01      4  city of london          77101  E09000001          7.0
# 4 1995-05-01      5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag  year
# 0           NaN             1  1995
# 1           NaN             1  1995
# 2           NaN             1  1995
# 3           NaN             1  1995
# 4           NaN             1  1995

# %% [markdown]
# C. Drop columns "month" and "year".

# %%
housing_data.drop(['month','year'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 housing_data.drop(['month','year'], axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
# ...

# %%
housing_data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %% [markdown]
# D. Show all the records where the 'No. of Crimes' is 0. And. how many such records are there?

# %%
housing_data[housing_data.no_of_crimes == 0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes  borough_flag
# 72            0.0             1
# 73            0.0             1
# ...

# %% [markdown]
# E. What is the maximum and minimum average price per year in England?

# %%
housing_data['year'] = housing_data.date.dt.year
df1 = housing_data[housing_data.area == 'england']
df1.head()
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
#
#        no_of_crimes  borough_flag  year
# 13248           NaN             0  1995
# 13249           NaN             0  1995
# 13250           NaN             0  1995
# 13251           NaN             0  1995
# 13252           NaN             0  1995

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# F. What is the maximum and minimum number of crimes recorded per area?

# %%
housing_data.groupby('area').no_of_crimes.min()
# Out:
# area
# barking and dagenham      1217.0
# barnet                    1703.0
# bexley                     860.0
# brent                     1850.0
# bromley                   1441.0
# camden                    2079.0
# city of london               0.0
# croydon                   2031.0
# ealing                    1871.0
# east midlands                NaN
# east of england              NaN
# enfield                   1635.0
# england                      NaN
# greenwich                 1513.0
# hackney                   1870.0
# hammersmith and fulham    1323.0
# haringey                  1536.0
# harrow                     937.0
# havering                  1130.0
# hillingdon                1445.0
# hounslow                  1529.0
# inner london                 NaN
# islington                 1871.0
# kensington and chelsea    1347.0
# kingston upon thames       692.0
# lambeth                   2381.0
# lewisham                  1675.0
# london                       NaN
# ...

# %%
housing_data.groupby('area').no_of_crimes.max()
# Out:
# area
# barking and dagenham      2049.0
# barnet                    2893.0
# bexley                    1914.0
# brent                     2937.0
# bromley                   2637.0
# camden                    4558.0
# city of london              10.0
# croydon                   3263.0
# ealing                    3401.0
# east midlands                NaN
# east of england              NaN
# enfield                   2798.0
# england                      NaN
# greenwich                 2853.0
# hackney                   3466.0
# hammersmith and fulham    2645.0
# haringey                  3199.0
# harrow                    1763.0
# havering                  1956.0
# hillingdon                2819.0
# hounslow                  2817.0
# inner london                 NaN
# islington                 3384.0
# kensington and chelsea    2778.0
# kingston upon thames      1379.0
# lambeth                   4701.0
# lewisham                  2813.0
# london                       NaN
# ...

# %% [markdown]
# G. Show the total count of records of each area, where the average price is less than 100000.

# %%
housing_data[housing_data.average_price < 100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
